# %% [markdown]
# # Cohort and grouping
#
# This notebook uses six generated records to show why an image-level split can flatter a model that remembers a lesion. These numbers are illustrative, not Skin Lesion Lab results. The real protocol groups lesion and known-duplicate links; patient identity remains unavailable. See [the protocol](../docs/evaluation-protocol.md).

# %%
from src.notebook_story import synthetic_demo

demo = synthetic_demo()
assert demo["kind"] == "illustrative synthetic data"
print(demo)

# %% [markdown]
# The first split repeats group identities across the boundary; the second holds out whole groups. The demonstration uses the same endpoint implementation as the benchmark, but its probabilities are constructed, not fitted. A 0.5 grouped ROC-AUC here shows the failure of memorization on this toy example. It says nothing about the measured model rankings.
